# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Snehal\Desktop\desktop\DSA_By_Krish\venv\python.exe

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
# !pip install -U langchain langchain-community
# Out:
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached sqlalchemy-2.0.44-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached aiohttp-3.13.2-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# ...
#   Using cached multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# ...
#
#    ---------------------------------------- 0/2 [soupsieve]
#    ---------------------------------------- 0/2 [soupsieve]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-33460")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Nike Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': '12 Months Head Coach (Senior Store Manager), Nike - Brisbane Airport',
#   'experience': None,
#   'skills': None,
#   'description': 'R-73333, Brisbane, Queensland, Australia, Retail Stores'},
#  {'role': 'Allocator, Korea',
#   'experience': None,
#   'skills': None,
#   'description': 'R-72254, Seoul, Seoul, South Korea, Planning & Inventory Management'},
#  {'role': 'Athlete III',
#   'experience': None,
#   'skills': None,
#   'description': 'R-73520, Shanghai, Shanghai, China, Retail Stores'},
#  {'role': 'Allocator, Japan',
#   'experience': None,
#   'skills': None,
#   'description': 'R-72364, Tokyo, Tokyo, Japan, Planning & Inventory Management'},
#  {'role': 'Analyst, Finance GC',
#   'experience': None,
#   'skills': None,
#   'description': 'R-58833, Taipei, Taipei City, Taiwan, Finance & Accounting'},
#  {'role': 'Assistant Head Coach (Assistant Store Manager) - NFS Palmanova Outlet Village',
#   'experience': None,
#   'skills': None,
# ...

# %%
type(json_res)
# Out:
# list

# %%
type(res.content)
print(res.content[:500])
# Out:
# ```json
# [
#   {
#     "role": "12 Months Head Coach (Senior Store Manager), Nike - Brisbane Airport",
#     "experience": null,
#     "skills": null,
#     "description": "R-73333, Brisbane, Queensland, Australia, Retail Stores"
#   },
#   {
#     "role": "Allocator, Korea",
#     "experience": null,
#     "skills": null,
#     "description": "R-72254, Seoul, Seoul, South Korea, Planning & Inventory Management"
#   },
#   {
#     "role": "Athlete III",
#     "experience": null,
#     "skills": null,
#     "description": "R-73520

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
print(type(collection))
# Out:
# <class 'chromadb.api.models.Collection.Collection'>

# %%
for job_item in job:
    # Use skills if available, otherwise fall back to role or description
    if job_item.get("skills"):
        query_texts = job_item["skills"]
        # Make sure it's a list (not a string)
        if isinstance(query_texts, str):
            query_texts = [query_texts]
    else:
        query_texts = [job_item["role"], job_item["description"]]

    # Perform the vector search
    result = collection.query(query_texts=query_texts, n_results=2)

    # Extract metadata (links or other stored info)
    links = result.get("metadatas", [[]])[0]
    print(f"Job: {job_item['role']}")
    print("Links:", links)
    print("-" * 50)
# Out:
# Job: 12 Months Head Coach (Senior Store Manager), Nike - Brisbane Airport
# Links: [{'links': 'https://example.com/ml-python-portfolio'}, {'links': 'https://example.com/xamarin-portfolio'}]
# --------------------------------------------------
# Job: Allocator, Korea
# Links: [{'links': 'https://example.com/android-tv-portfolio'}, {'links': 'https://example.com/android-portfolio'}]
# --------------------------------------------------
# Job: Athlete III
# Links: [{'links': 'https://example.com/android-tv-portfolio'}, {'links': 'https://example.com/ml-python-portfolio'}]
# --------------------------------------------------
# Job: Allocator, Japan
# Links: [{'links': 'https://example.com/android-portfolio'}, {'links': 'https://example.com/ios-portfolio'}]
# --------------------------------------------------
# Job: Analyst, Finance GC
# Links: [{'links': 'https://example.com/ml-python-portfolio'}, {'links': 'https://example.com/ios-portfolio'}]
# ...

# %%
job
# Out:
# [{'role': '12 Months Head Coach (Senior Store Manager), Nike - Brisbane Airport',
#   'experience': None,
#   'skills': None,
#   'description': 'R-73333, Brisbane, Queensland, Australia, Retail Stores'},
#  {'role': 'Allocator, Korea',
#   'experience': None,
#   'skills': None,
#   'description': 'R-72254, Seoul, Seoul, South Korea, Planning & Inventory Management'},
#  {'role': 'Athlete III',
#   'experience': None,
#   'skills': None,
#   'description': 'R-73520, Shanghai, Shanghai, China, Retail Stores'},
#  {'role': 'Allocator, Japan',
#   'experience': None,
#   'skills': None,
#   'description': 'R-72364, Tokyo, Tokyo, Japan, Planning & Inventory Management'},
#  {'role': 'Analyst, Finance GC',
#   'experience': None,
#   'skills': None,
#   'description': 'R-58833, Taipei, Taipei City, Taiwan, Finance & Accounting'},
#  {'role': 'Assistant Head Coach (Assistant Store Manager) - NFS Palmanova Outlet Village',
#   'experience': None,
#   'skills': None,
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Revolutionize Your Business Operations with AtliQ's Automated Solutions
#
# Dear Hiring Manager,
#
# I came across the job postings for various roles at Nike, including Head Coach, Allocator, Athlete III, and Assistant Head Coach, among others. As a business development executive at AtliQ, I believe our company can help streamline your business processes and enhance overall efficiency.
#
# At AtliQ, we specialize in providing AI-powered and software consulting services that cater to the unique needs of businesses like yours. Our expertise lies in developing tailored solutions that foster scalability, process optimization, cost reduction, and heightened overall efficiency. We have a proven track record of empowering numerous enterprises with our automated tools, and I'd love to explore how we can support Nike's operations.
#
# ...
