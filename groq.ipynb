# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-1.0.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.33.0-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain-groq)
#   Downloading langchain_core-1.0.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting anyio<5,>=3.5.0 (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting distro<2,>=1.7.0 (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3,>=1.9.0 (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting sniffio (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.10 (from groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Downloading langsmith-0.4.40-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\snehal\desktop\desktop\dsa_by_krish\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-groq) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Downloading orjson-3.11.4-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Downloading pydantic_core-2.41.4-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-groq)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Downloading langchain_groq-1.0.0-py3-none-any.whl (16 kB)
# Downloading groq-0.33.0-py3-none-any.whl (135 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading langchain_core-1.0.3-py3-none-any.whl (469 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.40-py3-none-any.whl (399 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 390.1 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.5/2.0 MB 390.1 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.0 MB 441.7 kB/s eta 0:00:03
#    --------------- ------------------------ 0.8/2.0 MB 441.7 kB/s eta 0:00:03
#    --------------- ------------------------ 0.8/2.0 MB 441.7 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 423.0 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 423.0 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.0 MB 423.0 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.0 MB 424.7 kB/s eta 0:00:02
#    ------------------------------ --------- 1.6/2.0 MB 484.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 484.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 484.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 484.9 kB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 455.5 kB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 455.5 kB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 444.0 kB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.4-cp312-cp312-win_amd64.whl (131 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, urllib3, typing-extensions, tenacity, sniffio, pyyaml, orjson, jsonpointer, idna, h11, distro, charset_normalizer, certifi, annotated-types, typing-inspection, requests, pydantic-core, jsonpatch, httpcore, anyio, requests-toolbelt, pydantic, httpx, langsmith, groq, langchain-core, langchain-groq
#
#    ----------------------------------------  0/27 [zstandard]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    - --------------------------------------  1/27 [urllib3]
#    -- -------------------------------------  2/27 [typing-extensions]
#    -- -------------------------------------  2/27 [typing-extensions]
#    ---- -----------------------------------  3/27 [tenacity]
#    ---- -----------------------------------  3/27 [tenacity]
#    ---- -----------------------------------  3/27 [tenacity]
#    ---- -----------------------------------  3/27 [tenacity]
#    ----- ----------------------------------  4/27 [sniffio]
#    ------- --------------------------------  5/27 [pyyaml]
#    ------- --------------------------------  5/27 [pyyaml]
#    ------- --------------------------------  5/27 [pyyaml]
#    ------- --------------------------------  5/27 [pyyaml]
#    ------- --------------------------------  5/27 [pyyaml]
#    -------- -------------------------------  6/27 [orjson]
#    ---------- -----------------------------  7/27 [jsonpointer]
#    ----------- ----------------------------  8/27 [idna]
#    ----------- ----------------------------  8/27 [idna]
#    ----------- ----------------------------  8/27 [idna]
#    ------------- --------------------------  9/27 [h11]
#    ------------- --------------------------  9/27 [h11]
#    ------------- --------------------------  9/27 [h11]
#    ------------- --------------------------  9/27 [h11]
#    ------------- --------------------------  9/27 [h11]
#    -------------- ------------------------- 10/27 [distro]
#    -------------- ------------------------- 10/27 [distro]
#    -------------- ------------------------- 10/27 [distro]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ---------------- ----------------------- 11/27 [charset_normalizer]
#    ----------------- ---------------------- 12/27 [certifi]
#    ------------------- -------------------- 13/27 [annotated-types]
#    -------------------- ------------------- 14/27 [typing-inspection]
#    ---------------------- ----------------- 15/27 [requests]
#    ---------------------- ----------------- 15/27 [requests]
#    ---------------------- ----------------- 15/27 [requests]
#    ---------------------- ----------------- 15/27 [requests]
#    ---------------------- ----------------- 15/27 [requests]
#    ----------------------- ---------------- 16/27 [pydantic-core]
#    ------------------------- -------------- 17/27 [jsonpatch]
#    ------------------------- -------------- 17/27 [jsonpatch]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    -------------------------- ------------- 18/27 [httpcore]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ---------------------------- ----------- 19/27 [anyio]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ----------------------------- ---------- 20/27 [requests-toolbelt]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    ------------------------------- -------- 21/27 [pydantic]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    -------------------------------- ------- 22/27 [httpx]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ---------------------------------- ----- 23/27 [langsmith]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ----------------------------------- ---- 24/27 [groq]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    ------------------------------------- -- 25/27 [langchain-core]
#    -------------------------------------- - 26/27 [langchain-groq]
#    -------------------------------------- - 26/27 [langchain-groq]
#    ---------------------------------------- 27/27 [langchain-groq]
#
# Successfully installed annotated-types-0.7.0 anyio-4.11.0 certifi-2025.10.5 charset_normalizer-3.4.4 distro-1.9.0 groq-0.33.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-1.0.3 langchain-groq-1.0.0 langsmith-0.4.40 orjson-3.11.4 pydantic-2.12.3 pydantic-core-2.41.4 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.5.0 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000211832B1B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain-groq/

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.
